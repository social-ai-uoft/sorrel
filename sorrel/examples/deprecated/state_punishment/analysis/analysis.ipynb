# %%
import tensorflow as tf
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
import tensorflow as tf
import csv


def tensorboard_to_csv(event_file, csv_file):
    """
    Convert TensorBoard event file data to a CSV format.

    Args:
        event_file (str): Path to the TensorBoard event file (e.g., events.out.tfevents.xxx).
        csv_file (str): Path where the output CSV file should be saved.
    """
    # Create a list to store the data rows
    data_rows = []

    # Use tf.compat.v1 to access the summary_iterator in TensorFlow 2.x
    for e in tf.compat.v1.train.summary_iterator(event_file):
        for v in e.summary.value:
            # Only consider scalar summaries
            if v.HasField("simple_value"):
                tag = v.tag
                value = v.simple_value
                step = e.step
                data_rows.append([step, tag, value])

    # Write the extracted data into a CSV file
    with open(csv_file, "w", newline="") as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(["Step", "Tag", "Value"])
        # Write the data rows
        writer.writerows(data_rows)

    print(f"Data from {event_file} has been written to {csv_file}")

# %%
import tensorflow as tf
import csv
from collections import defaultdict

# def tensorboard_to_separate_csv(event_file, output_dir):
#     """
#     Convert TensorBoard event file data to separate CSV files based on tags.

#     Args:
#         event_file (str): Path to the TensorBoard event file (e.g., events.out.tfevents.xxx).
#         output_dir (str): Directory where the CSV files should be saved. One CSV per tag.
#     """
#     # Create a dictionary to store data by tag
#     tag_data = defaultdict(list)

#     # Use tf.compat.v1 to access the summary_iterator in TensorFlow 2.x
#     for e in tf.compat.v1.train.summary_iterator(event_file):
#         for v in e.summary.value:
#             # Only consider scalar summaries
#             if v.HasField('simple_value'):
#                 tag = v.tag
#                 value = v.simple_value
#                 step = e.step
#                 tag_data[tag].append([step, value])

#     # Save each tag's data in a separate CSV file
#     for tag, data_rows in tag_data.items():
#         # Create a valid filename based on the tag
#         filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"  # Replace slashes with underscores for filename safety

#         with open(filename, 'w', newline='') as file:
#             writer = csv.writer(file)
#             # Write the header
#             writer.writerow(['Step', 'Value'])
#             # Write the data rows
#             writer.writerows(data_rows)

#         print(f"Data for tag '{tag}' has been written to {filename}")

# %%
def tensorboard_to_separate_csv(event_file, output_dir):
    from tensorflow.python.framework.errors_impl import DataLossError
    from collections import defaultdict
    import os, csv

    tag_data = defaultdict(list)
    try:
        for e in tf.compat.v1.train.summary_iterator(event_file):
            for v in e.summary.value:
                if v.HasField("simple_value"):
                    tag = v.tag
                    value = v.simple_value
                    step = e.step
                    tag_data[tag].append([step, value])
    except DataLossError:
        print(f"Skipped corrupted file: {event_file}")
        return  # Exit this function for corrupted file

    # Save tag data to CSV files
    for tag, data_rows in tag_data.items():
        filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"
        with open(filename, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Step", "Value"])
            writer.writerows(data_rows)
        print(f"Data for tag '{tag}' has been written to {filename}")

# %%
def tensorboard_to_separate_csv(event_file, output_dir):
    from tensorflow.python.framework.errors_impl import DataLossError
    from collections import defaultdict
    import os, csv
    import tensorflow as tf

    tag_data = defaultdict(list)

    try:
        for e in tf.compat.v1.train.summary_iterator(event_file):
            try:
                # Process individual records
                for v in e.summary.value:
                    if v.HasField("simple_value"):
                        tag = v.tag
                        value = v.simple_value
                        step = e.step
                        tag_data[tag].append([step, value])
            except Exception as record_error:
                # Log a warning and skip problematic records
                print(f"Skipped a corrupt record in file: {event_file}")
    except DataLossError:
        # Log and continue for files with partial writes
        print(
            f"Encountered DataLossError. Possibly due to incomplete writes in file: {event_file}"
        )

    # Save tag data to CSV files
    for tag, data_rows in tag_data.items():
        filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"
        with open(filename, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Step", "Value"])
            writer.writerows(data_rows)
        print(f"Data for tag '{tag}' has been written to {filename}")

# %%
import os
import time


def process_tensorboard_results(parent_dir, output_parent_dir):
    """
    Loop through all subdirectories of a parent directory, process TensorBoard files,
    and save results to a corresponding directory structure.

    Args:
        parent_dir (str): Parent directory containing TensorBoard event files.
        output_parent_dir (str): Parent directory where CSV files should be saved.
    """
    for root, dirs, files in os.walk(parent_dir):
        for file in files:
            if "tfevents" in file:  # Check if the file is a TensorBoard event file
                # Full path to the event file
                event_file = os.path.join(root, file)

                # Recreate the directory structure in the output directory
                relative_path = os.path.relpath(root, parent_dir)
                output_dir = os.path.join(output_parent_dir, relative_path)

                # Create the output directory if it doesn't exist
                os.makedirs(output_dir, exist_ok=True)

                # Process the TensorBoard event file
                tensorboard_to_separate_csv(event_file, output_dir)

                print(f"Processed {event_file} -> {output_dir}")

# %%
def is_file_stable(file_path, wait_time=1.0):
    initial_size = os.path.getsize(file_path)
    time.sleep(wait_time)
    final_size = os.path.getsize(file_path)
    return initial_size == final_size


def process_tensorboard_results(parent_dir, output_parent_dir):
    """
    Loop through all subdirectories of a parent directory, process TensorBoard files,
    and save results to a corresponding directory structure.

    Args:
        parent_dir (str): Parent directory containing TensorBoard event files.
        output_parent_dir (str): Parent directory where CSV files should be saved.
    """
    for root, dirs, files in os.walk(parent_dir):
        for file in files:
            if "tfevents" in file:  # Check if the file is a TensorBoard event file
                event_file = os.path.join(root, file)
                relative_path = os.path.relpath(root, parent_dir)
                output_dir = os.path.join(output_parent_dir, relative_path)
                os.makedirs(output_dir, exist_ok=True)

                # Check if the file is stable
                if not is_file_stable(event_file):
                    print(f"File is still being written: {event_file}, skipping.")
                    continue

                try:
                    tensorboard_to_separate_csv(event_file, output_dir)
                    print(f"Processed {event_file} -> {output_dir}")
                except Exception as e:
                    print(f"Failed to process {event_file}: {e}")

# %%
tensorboard_to_separate_csv(
    "../runs/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/events.out.tfevents.1734363312.SocialAIs-Mac-Studio-3.local.2634.0",
    "res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
)
# Out:
# Encountered DataLossError. Possibly due to incomplete writes in file: ../runs/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/events.out.tfevents.1734363312.SocialAIs-Mac-Studio-3.local.2634.0
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_2_Epsilon_data.csv
# Data for tag 'Agent_2/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_2_vote_for_punishment_data.csv
# Data for tag 'Agent_2/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/Agent_2_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312/state_punishment_level_init_data.csv

# %%
def exponential_moving_average(data, alpha):
    """
    Calculate the exponential moving average (EMA) of a 1D array.

    Args:
        data (array-like): The input data.
        alpha (float): The smoothing factor (0 < alpha <= 1).

    Returns:
        numpy.ndarray: The EMA values.
    """
    if not (0 < alpha <= 1):
        raise ValueError("Alpha must be between 0 and 1.")

    ema = [data[0]]  # Initialize EMA with the first data point
    for i in range(1, len(data)):
        ema.append(alpha * data[i] + (1 - alpha) * ema[-1])
    return np.array(ema)


import numpy as np


def rolling_average(data, window_size):
    """
    Calculate the rolling average of a 1D array.

    Args:
        data (array-like): The input data.
        window_size (int): The size of the rolling window.

    Returns:
        numpy.ndarray: The rolling average values.
    """
    if window_size < 1:
        raise ValueError("Window size must be at least 1.")
    if len(data) < window_size:
        raise ValueError("Data length must be at least equal to the window size.")

    # Use np.convolve for efficient computation
    weights = np.ones(window_size) / window_size
    return np.convolve(data, weights, mode="valid")


def plot_average_trajectory(
    time_series,
    error_type="std",
    time_points=None,
    xlabel="Time",
    ylabel="Value",
    title="Average Trajectory",
):
    """
    Plots the average trajectory of a set of time series with error bars.

    Parameters:
    - time_series (2D array-like): A set of time series, shape (n_series, n_time_points).
    - error_type (str): Either 'std' for standard deviation or 'sem' for standard error.
    - time_points (1D array-like, optional): Time points corresponding to the time series. Defaults to indices.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - title (str): Title of the plot.
    """
    time_series = np.array(time_series)
    if time_points is None:
        time_points = np.arange(time_series.shape[1])
    else:
        time_points = np.array(time_points)

    if time_series.shape[1] != len(time_points):
        raise ValueError(
            "Length of time_points must match the number of columns in time_series."
        )

    # Compute average and error
    mean_trajectory = np.mean(time_series, axis=0)
    if error_type == "std":
        error = np.std(time_series, axis=0)
    elif error_type == "sem":
        error = np.std(time_series, axis=0) / np.sqrt(time_series.shape[0])
    else:
        raise ValueError("error_type must be 'std' or 'sem'.")

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(time_points, mean_trajectory, label="Mean Trajectory", color="blue")
    plt.fill_between(
        time_points,
        mean_trajectory - error,
        mean_trajectory + error,
        alpha=0.3,
        color="blue",
        label="Error",
    )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(False)
    plt.show()

# %%
parent_dir = "../runs"
output_dir = "res"
process_tensorboard_results(parent_dir, output_dir)
# Out:
# Skipped corrupted file: ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/events.out.tfevents.1732996371.SocialAIs-Mac-Studio-3.local.52665.0
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/events.out.tfevents.1732996371.SocialAIs-Mac-Studio-3.local.52665.0 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Wall/events.out.tfevents.1732996372.SocialAIs-Mac-Studio-3.local.52665.3 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Gem/events.out.tfevents.1732996372.SocialAIs-Mac-Studio-3.local.52665.1 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Coin/events.out.tfevents.1732996372.SocialAIs-Mac-Studio-3.local.52665.2 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.01_onehot_5channel_20241130-14111732996371/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/events.out.tfevents.1732807364.SocialAIs-Mac-Studio-3.local.30338.0 -> res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Wall/events.out.tfevents.1732807364.SocialAIs-Mac-Studio-3.local.30338.3 -> res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Gem/events.out.tfevents.1732807364.SocialAIs-Mac-Studio-3.local.30338.1 -> res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Coin/events.out.tfevents.1732807364.SocialAIs-Mac-Studio-3.local.30338.2 -> res/fixed_punishment_rate_0.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807364/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/events.out.tfevents.1732317157.SocialAIs-Mac-Studio-3.local.75601.0 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Wall/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.6 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Wall/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.3 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Gem/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.4 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Gem/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.1 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Coin/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.5 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Coin/events.out.tfevents.1732317159.SocialAIs-Mac-Studio-3.local.75601.2 -> res/fixed_punishment_rate_1.0_twoAs_20241122-18111732317157/Agent_0_Encounters_Coin
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/events.out.tfevents.1732575310.SocialAIs-Mac-Studio-3.local.83846.0 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Wall/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.3 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Wall/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.6 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Gem/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.1 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Gem/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.4 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Coin/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.2 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Coin/events.out.tfevents.1732575311.SocialAIs-Mac-Studio-3.local.83846.5 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_no_value_20241125-17111732575310/Agent_0_Encounters_Coin
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/events.out.tfevents.1732562584.SocialAIs-Mac-Studio-3.local.82818.0 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Wall/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.3 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Wall/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.6 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Gem/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.1 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Gem/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.4 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Coin/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.2 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Coin/events.out.tfevents.1732562586.SocialAIs-Mac-Studio-3.local.82818.5 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-14111732562584/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/Epsilon' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Epsilon_data.csv
# Data for tag 'Agent_2/vote_for_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_vote_for_punishment_data.csv
# Data for tag 'Agent_2/vote_against_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_vote_against_punishment_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/events.out.tfevents.1733788152.SocialAIs-Mac-Studio-3.local.14831.0 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Bone/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.3 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Bone
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Coin/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Coin/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.6 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Coin
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Wall/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.12 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Wall/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.4 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Bone/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Bone/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.11 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Bone
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Wall/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Wall/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.8 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Gem/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.9 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Gem/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.1 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Coin/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.10 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_1_Encounters_Coin
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Bone/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Bone/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.7 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Coin/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.2 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_0_Encounters_Coin
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Gem/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Gem/events.out.tfevents.1733788154.SocialAIs-Mac-Studio-3.local.14831.5 -> res/fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152/Agent_2_Encounters_Gem
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/events.out.tfevents.1732807387.SocialAIs-Mac-Studio-3.local.30376.0 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Wall/events.out.tfevents.1732807387.SocialAIs-Mac-Studio-3.local.30376.3 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Gem/events.out.tfevents.1732807387.SocialAIs-Mac-Studio-3.local.30376.1 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Coin/events.out.tfevents.1732807387.SocialAIs-Mac-Studio-3.local.30376.2 -> res/fixed_punishment_rate_1.0_oneAs_size16_gem_has_value_epsilon0.99_20241128-10111732807387/Agent_0_Encounters_Coin
# Skipped corrupted file: ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.0
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.0 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Wall/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.3 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Wall
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Wall/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.6 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Wall
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Gem/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.1 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Gem
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Gem/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.4 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Gem
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Coin/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.2 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_1_Encounters_Coin
# Processed ../runs/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Coin/events.out.tfevents.1732574693.SocialAIs-Mac-Studio-3.local.83603.5 -> res/fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_20241125-17111732574693/Agent_0_Encounters_Coin
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Epsilon_data.csv
# Data for tag 'Agent_2/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_vote_for_punishment_data.csv
# Data for tag 'Agent_2/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/events.out.tfevents.1733788342.SocialAIs-Mac-Studio-3.local.14969.0 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Bone/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.11 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Bone
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Coin/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Coin/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.6 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Coin
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Wall/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.4 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Wall/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.12 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Bone/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Bone/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.3 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Bone
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Wall/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Wall/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.8 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Gem/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.1 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Gem/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.9 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Coin/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.2 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_1_Encounters_Coin
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Bone/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Bone/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.7 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Coin/events.out.tfevents.1733788345.SocialAIs-Mac-Studio-3.local.14969.10 -> res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_0_Encounters_Coin
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342/Agent_2_Encounters_Gem/Agent_2_Encounters_data.csv
# ...
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/events.out.tfevents.1732638747.SocialAIs-Mac-Studio-3.local.88218.0 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Wall/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.6 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Wall/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.3 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Gem/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.4 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Gem/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.1 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Coin/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.5 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Coin/events.out.tfevents.1732638748.SocialAIs-Mac-Studio-3.local.88218.2 -> res/fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/Epsilon' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Epsilon_data.csv
# Data for tag 'Agent_2/vote_for_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_vote_for_punishment_data.csv
# Data for tag 'Agent_2/vote_against_punishment' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/state_punishment_level_init_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/events.out.tfevents.1733157261.SocialAIs-Mac-Studio-3.local.65108.0 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Coin/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Coin/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.8 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Coin
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Wall/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.6 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Wall/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.3 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Wall
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Wall/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Wall/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.9 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Gem/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.4 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Gem/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.1 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Coin/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.5 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Coin/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.2 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_0_Encounters_Coin
# Data for tag 'Agent_2/Encounters' has been written to res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Gem/Agent_2_Encounters_data.csv
# Processed ../runs/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Gem/events.out.tfevents.1733157264.SocialAIs-Mac-Studio-3.local.65108.7 -> res/fixed_punishment_rate_0.0_sixAs_size15_init_spawn_0.2_20241202-11121733157261/Agent_2_Encounters_Gem
# Data for tag 'Agent_0/Loss' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/state_punishment_level_init_data.csv
# Processed ../runs/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/events.out.tfevents.1732316295.SocialAIs-Mac-Studio-3.local.75345.0 -> res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Wall/events.out.tfevents.1732316296.SocialAIs-Mac-Studio-3.local.75345.3 -> res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Gem/events.out.tfevents.1732316296.SocialAIs-Mac-Studio-3.local.75345.1 -> res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Coin/events.out.tfevents.1732316296.SocialAIs-Mac-Studio-3.local.75345.2 -> res/fixed_full_punishment_rate_control_cond_v2_avoid_poison_item_allow_to_hit_wall_20241122-17111732316295/Agent_0_Encounters_Coin

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def trim_and_calculate_mean(array_list):
    # Find the minimum length among all arrays
    min_length = min(len(arr) for arr in array_list)

    # Trim each array to the minimum length
    trimmed_arrays = [arr[:min_length] for arr in array_list]

    # Convert to a NumPy array for vectorized mean calculation
    trimmed_arrays = np.array(trimmed_arrays)

    return trimmed_arrays

# %% [markdown]
# reward

# %%
# folders = [
#     # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
#     'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     'fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845',
#     'fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747',
#     'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804',

# ]

# folders = [
#     'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_2_20241202-17121733176970',
#     'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_3_20241202-17121733176981',
#     'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_4_20241202-17121733176995',
#     'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_5_20241202-17121733177002',
# ]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788277",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241210-12121733853538",
]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363250",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363157",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363072",
]
collective_rs = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join("res", folder)
    files = os.listdir(parent_dir)

    for f in files:
        if "Reward" in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_rs[ixs].append(data["Value"].to_numpy()[:])
collective_rs_ = [
    np.mean(trim_and_calculate_mean(collective_rs[i]), axis=0)
    for i in range(len(collective_rs))
]

# %%
smoothed_collective_rs_ = [rolling_average(d, 50) for d in collective_rs_]
plot_average_trajectory(smoothed_collective_rs_, "sem", title="reward")

# %%
labels = ["1.0", "0.75,", "0.25", "0.0"]
labels = ["1.0", "0.0"]
labels = [f"{i}" for i in range(4)]
labels = ["0.0_0.0_1", "0.0_0.4_1.0", "0.2_0.6_1.0", "0.0_0.0_0.0"]

alpha = 0.2
wsize = 25
for ixs, d in enumerate(collective_rs_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title("Mean R")
# Out:
# Text(0.5, 1.0, 'Mean R')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4 * len(labels), 4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective_rs[i])):
        axes[i].plot(rolling_average(collective_rs[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle("Reward")
# Out:
# Text(0.5, 0.98, 'Reward')

# %% [markdown]
# encounter_coins

# %%
# folders = [
#     # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
#     'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     'fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845',
#     'fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747',
#     'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804',

# ]

folders = [
    "fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_2_20241202-17121733176970",
    "fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_3_20241202-17121733176981",
    "fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_4_20241202-17121733176995",
    "fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_5_20241202-17121733177002",
]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788277",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241210-12121733853538",
]


folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363250",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363157",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363072",
]

entity_name = "Coin"
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join("res", folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data["Value"].to_numpy()[:])  # trim if needed

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
labels = ["1.0", "0.75,", "0.25", "0.0"]
labels = ["1.0", "0.0"]
labels = [f"{i}" for i in range(1)]
labels = ["0.0_0.0_1", "0.0_0.4_1.0", "0.2_0.6_1.0", "0.0_0.0_0.0"]

alpha = 0.2
wsize = 100
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title("Coin")
# Out:
# Text(0.5, 1.0, 'Coin')

# %%
smoothed_collective_ = [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, "sem", title="coin")

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4 * len(labels), 4))
wsize = 100
for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle("Coin")
# Out:
# Text(0.5, 0.98, 'Coin')

# %%
folders = [
    # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
    # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
    "fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891",
    "fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845",
    "fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747",
    "fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804",
]


folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788277",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241210-12121733853538",
]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363250",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363157",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363072",
]

entity_name = "Gem"
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join("res", folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data["Value"].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
labels = ["1.0", "0.75,", "0.25", "0.0"]
labels = ["1.0", "0.0"]
labels = [f"{i}" for i in range(4)]
labels = ["0.0_0.0_1", "0.0_0.4_1.0", "0.2_0.6_1.0", "0.0_0.0_0.0"]

alpha = 0.2
wsize = 25
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title("Gem")
# Out:
# Text(0.5, 1.0, 'Gem')

# %%
smoothed_collective_ = [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, "sem", title="gem")

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4 * len(labels), 4))
wsize = 500

for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle("Gem")
# Out:
# Text(0.5, 0.98, 'Gem')

# %% [markdown]
# bone

# %%
folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788277",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241210-12121733853538",
]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363250",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363157",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363072",
]

entity_name = "Bone"
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join("res", folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data["Value"].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
labels = ["0.0_0.0_1", "0.0_0.4_1.0", "0.2_0.6_1.0", "0.0_0.0_0.0"]

alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title("Bone")
# Out:
# Text(0.5, 1.0, 'Bone')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4 * len(labels), 4))
wsize = 500

for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle("Bone")
# Out:
# Text(0.5, 0.98, 'Bone')

# %% [markdown]
# wall

# %%
folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788277",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788342",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241209-18121733788152",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_20241210-12121733853538",
]

folders = [
    "fixed_punishment_rate_0.0_0.0_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363312",
    "fixed_punishment_rate_0.0_0.4_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363250",
    "fixed_punishment_rate_0.2_0.6_1.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363157",
    "fixed_punishment_rate_0.0_0.0_0.0_3As_size15_3Resources_ambiguity_v2_init0.2_resume_20241216-10121734363072",
]

entity_name = "Wall"
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join("res", folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data["Value"].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
labels = ["0_0_1", "0_0.4_1", "0.2_0.6_1.0", "0.0_0.0_0.0"]

alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title("Wall")
# Out:
# Text(0.5, 1.0, 'Wall')
