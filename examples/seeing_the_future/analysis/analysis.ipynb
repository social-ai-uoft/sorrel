# %%
import tensorflow as tf
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
import tensorflow as tf
import csv

def tensorboard_to_csv(event_file, csv_file):
    """
    Convert TensorBoard event file data to a CSV format.

    Args:
        event_file (str): Path to the TensorBoard event file (e.g., events.out.tfevents.xxx).
        csv_file (str): Path where the output CSV file should be saved.
    """
    # Create a list to store the data rows
    data_rows = []
    
    # Use tf.compat.v1 to access the summary_iterator in TensorFlow 2.x
    for e in tf.compat.v1.train.summary_iterator(event_file):
        for v in e.summary.value:
            # Only consider scalar summaries
            if v.HasField('simple_value'):
                tag = v.tag
                value = v.simple_value
                step = e.step
                data_rows.append([step, tag, value])
    
    # Write the extracted data into a CSV file
    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['Step', 'Tag', 'Value'])
        # Write the data rows
        writer.writerows(data_rows)
    
    print(f"Data from {event_file} has been written to {csv_file}")

# %%
import tensorflow as tf
import csv
from collections import defaultdict

# def tensorboard_to_separate_csv(event_file, output_dir):
#     """
#     Convert TensorBoard event file data to separate CSV files based on tags.

#     Args:
#         event_file (str): Path to the TensorBoard event file (e.g., events.out.tfevents.xxx).
#         output_dir (str): Directory where the CSV files should be saved. One CSV per tag.
#     """
#     # Create a dictionary to store data by tag
#     tag_data = defaultdict(list)
    
#     # Use tf.compat.v1 to access the summary_iterator in TensorFlow 2.x
#     for e in tf.compat.v1.train.summary_iterator(event_file):
#         for v in e.summary.value:
#             # Only consider scalar summaries
#             if v.HasField('simple_value'):
#                 tag = v.tag
#                 value = v.simple_value
#                 step = e.step
#                 tag_data[tag].append([step, value])

#     # Save each tag's data in a separate CSV file
#     for tag, data_rows in tag_data.items():
#         # Create a valid filename based on the tag
#         filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"  # Replace slashes with underscores for filename safety
        
#         with open(filename, 'w', newline='') as file:
#             writer = csv.writer(file)
#             # Write the header
#             writer.writerow(['Step', 'Value'])
#             # Write the data rows
#             writer.writerows(data_rows)
        
#         print(f"Data for tag '{tag}' has been written to {filename}")

# %%
def tensorboard_to_separate_csv(event_file, output_dir):
    from tensorflow.python.framework.errors_impl import DataLossError
    from collections import defaultdict
    import os, csv
    
    tag_data = defaultdict(list)
    try:
        for e in tf.compat.v1.train.summary_iterator(event_file):
            for v in e.summary.value:
                if v.HasField('simple_value'):
                    tag = v.tag
                    value = v.simple_value
                    step = e.step
                    tag_data[tag].append([step, value])
    except DataLossError:
        print(f"Skipped corrupted file: {event_file}")
        return  # Exit this function for corrupted file

    # Save tag data to CSV files
    for tag, data_rows in tag_data.items():
        filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"
        with open(filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Step', 'Value'])
            writer.writerows(data_rows)
        print(f"Data for tag '{tag}' has been written to {filename}")

# %%
import os

def process_tensorboard_results(parent_dir, output_parent_dir):
    """
    Loop through all subdirectories of a parent directory, process TensorBoard files,
    and save results to a corresponding directory structure.

    Args:
        parent_dir (str): Parent directory containing TensorBoard event files.
        output_parent_dir (str): Parent directory where CSV files should be saved.
    """
    for root, dirs, files in os.walk(parent_dir):
        for file in files:
            if "tfevents" in file:  # Check if the file is a TensorBoard event file
                # Full path to the event file
                event_file = os.path.join(root, file)

                # Recreate the directory structure in the output directory
                relative_path = os.path.relpath(root, parent_dir)
                output_dir = os.path.join(output_parent_dir, relative_path)

                # Create the output directory if it doesn't exist
                os.makedirs(output_dir, exist_ok=True)

                # Process the TensorBoard event file
                tensorboard_to_separate_csv(event_file, output_dir)

                print(f"Processed {event_file} -> {output_dir}")

# %%
tensorboard_to_separate_csv('../runs/fixed_punishment_rate_0.0_sixAs_size16_gem_has_value_epsilon0.01_20241129-10111732895279/events.out.tfevents.1732895279.SocialAIs-Mac-Studio-3.local.38967.0', 'res/test')
# Out:
# Data for tag 'Agent_1/Loss' has been written to res/test/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/test/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/test/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/test/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/test/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/test/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/test/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/Epsilon' has been written to res/test/Agent_2_Epsilon_data.csv
# Data for tag 'Agent_2/vote_for_punishment' has been written to res/test/Agent_2_vote_for_punishment_data.csv
# Data for tag 'Agent_2/vote_against_punishment' has been written to res/test/Agent_2_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/test/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/test/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/test/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/test/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/test/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_5/Loss' has been written to res/test/Agent_5_Loss_data.csv
# Data for tag 'Agent_5/Reward' has been written to res/test/Agent_5_Reward_data.csv
# Data for tag 'Agent_5/Epsilon' has been written to res/test/Agent_5_Epsilon_data.csv
# Data for tag 'Agent_5/vote_for_punishment' has been written to res/test/Agent_5_vote_for_punishment_data.csv
# Data for tag 'Agent_5/vote_against_punishment' has been written to res/test/Agent_5_vote_against_punishment_data.csv
# Data for tag 'Agent_4/Loss' has been written to res/test/Agent_4_Loss_data.csv
# Data for tag 'Agent_4/Reward' has been written to res/test/Agent_4_Reward_data.csv
# Data for tag 'Agent_4/Epsilon' has been written to res/test/Agent_4_Epsilon_data.csv
# Data for tag 'Agent_4/vote_for_punishment' has been written to res/test/Agent_4_vote_for_punishment_data.csv
# Data for tag 'Agent_4/vote_against_punishment' has been written to res/test/Agent_4_vote_against_punishment_data.csv
# Data for tag 'Agent_3/Loss' has been written to res/test/Agent_3_Loss_data.csv
# Data for tag 'Agent_3/Reward' has been written to res/test/Agent_3_Reward_data.csv
# Data for tag 'Agent_3/Epsilon' has been written to res/test/Agent_3_Epsilon_data.csv
# Data for tag 'Agent_3/vote_for_punishment' has been written to res/test/Agent_3_vote_for_punishment_data.csv
# Data for tag 'Agent_3/vote_against_punishment' has been written to res/test/Agent_3_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/test/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/test/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/test/state_punishment_level_init_data.csv

# %%
def exponential_moving_average(data, alpha):
    """
    Calculate the exponential moving average (EMA) of a 1D array.

    Args:
        data (array-like): The input data.
        alpha (float): The smoothing factor (0 < alpha <= 1).

    Returns:
        numpy.ndarray: The EMA values.
    """
    if not (0 < alpha <= 1):
        raise ValueError("Alpha must be between 0 and 1.")

    ema = [data[0]]  # Initialize EMA with the first data point
    for i in range(1, len(data)):
        ema.append(alpha * data[i] + (1 - alpha) * ema[-1])
    return np.array(ema)

import numpy as np

def rolling_average(data, window_size):
    """
    Calculate the rolling average of a 1D array.

    Args:
        data (array-like): The input data.
        window_size (int): The size of the rolling window.

    Returns:
        numpy.ndarray: The rolling average values.
    """
    if window_size < 1:
        raise ValueError("Window size must be at least 1.")
    if len(data) < window_size:
        raise ValueError("Data length must be at least equal to the window size.")
    
    # Use np.convolve for efficient computation
    weights = np.ones(window_size) / window_size
    return np.convolve(data, weights, mode='valid')

def plot_average_trajectory(time_series, error_type='std', time_points=None, xlabel='Time', ylabel='Value', title='Average Trajectory'):
    """
    Plots the average trajectory of a set of time series with error bars.

    Parameters:
    - time_series (2D array-like): A set of time series, shape (n_series, n_time_points).
    - error_type (str): Either 'std' for standard deviation or 'sem' for standard error.
    - time_points (1D array-like, optional): Time points corresponding to the time series. Defaults to indices.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - title (str): Title of the plot.
    """
    time_series = np.array(time_series)
    if time_points is None:
        time_points = np.arange(time_series.shape[1])
    else:
        time_points = np.array(time_points)
    
    if time_series.shape[1] != len(time_points):
        raise ValueError("Length of time_points must match the number of columns in time_series.")
    
    # Compute average and error
    mean_trajectory = np.mean(time_series, axis=0)
    if error_type == 'std':
        error = np.std(time_series, axis=0)
    elif error_type == 'sem':
        error = np.std(time_series, axis=0) / np.sqrt(time_series.shape[0])
    else:
        raise ValueError("error_type must be 'std' or 'sem'.")
    
    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(time_points, mean_trajectory, label='Mean Trajectory', color='blue')
    plt.fill_between(time_points, mean_trajectory - error, mean_trajectory + error, alpha=0.3, color='blue', label='Error')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(False)
    plt.show()

# %%
parent_dir = '../runs'
output_dir = 'res'
process_tensorboard_results(parent_dir, output_dir)
# Out:
# WARNING:tensorflow:From /opt/homebrew/lib/python3.11/site-packages/tensorflow/python/summary/summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# Data for tag 'Agent_0/Loss' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_vote_against_punishment_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/state_punishment_level_init_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.0 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Wall/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.6 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Wall/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.3 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Gem/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.4 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Gem/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.1 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Coin/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.5 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Coin/events.out.tfevents.1733366965.SocialAIs-Mac-Studio-2.local.8697.2 -> res/control_no_punishment_no_prediction_size10_2resources_20241204-21121733366965/Agent_0_Encounters_Coin
# Data for tag 'Agent_1/Loss' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/Epsilon' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Epsilon_data.csv
# Data for tag 'Agent_1/vote_for_punishment' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_vote_for_punishment_data.csv
# Data for tag 'Agent_1/vote_against_punishment' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_vote_against_punishment_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/state_punishment_level_init_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/events.out.tfevents.1733367550.SocialAIs-Mac-Studio-2.local.8794.0 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Wall/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Wall/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.3 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Wall/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.6 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Wall
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Gem/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Gem/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.1 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Gem/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.4 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Gem
# Data for tag 'Agent_1/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Coin/Agent_1_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Coin/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.2 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_1_Encounters_Coin
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Coin/events.out.tfevents.1733367551.SocialAIs-Mac-Studio-2.local.8794.5 -> res/control_no_punishment_no_prediction_size7_maxstep20_2resources_20241204-21121733367550/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/events.out.tfevents.1733347731.SocialAIs-Mac-Studio-2.local.4732.0 -> res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Bone/events.out.tfevents.1733347731.SocialAIs-Mac-Studio-2.local.4732.3 -> res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Wall/events.out.tfevents.1733347731.SocialAIs-Mac-Studio-2.local.4732.4 -> res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Gem/events.out.tfevents.1733347731.SocialAIs-Mac-Studio-2.local.4732.1 -> res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Coin/events.out.tfevents.1733347731.SocialAIs-Mac-Studio-2.local.4732.2 -> res/old/fixed_punishment_rate_0.0_0.0_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347731/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/events.out.tfevents.1733347785.SocialAIs-Mac-Studio-2.local.4775.0 -> res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Bone/events.out.tfevents.1733347785.SocialAIs-Mac-Studio-2.local.4775.3 -> res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Wall/events.out.tfevents.1733347785.SocialAIs-Mac-Studio-2.local.4775.4 -> res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Gem/events.out.tfevents.1733347785.SocialAIs-Mac-Studio-2.local.4775.1 -> res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Coin/events.out.tfevents.1733347785.SocialAIs-Mac-Studio-2.local.4775.2 -> res/old/fixed_punishment_rate_0.0_0.0_0.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347785/Agent_0_Encounters_Coin
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/events.out.tfevents.1733347363.SocialAIs-Mac-Studio-2.local.4669.0
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/events.out.tfevents.1733347363.SocialAIs-Mac-Studio-2.local.4669.0 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Wall/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.3
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Wall/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.3 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Wall
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Gem/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.1
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Gem/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.1 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Gem
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Coin/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.2
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Coin/events.out.tfevents.1733347364.SocialAIs-Mac-Studio-2.local.4669.2 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347363/Agent_0_Encounters_Coin
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/events.out.tfevents.1733343185.SocialAIs-Mac-Studio-2.local.3534.0
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/events.out.tfevents.1733343185.SocialAIs-Mac-Studio-2.local.3534.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Wall/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.3
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Wall/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.3 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Wall
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Gem/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.1
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Gem/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.1 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Gem
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Coin/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.2
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Coin/events.out.tfevents.1733343186.SocialAIs-Mac-Studio-2.local.3534.2 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343185/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/events.out.tfevents.1733343140.SocialAIs-Mac-Studio-2.local.3494.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Wall/events.out.tfevents.1733343140.SocialAIs-Mac-Studio-2.local.3494.3 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Gem/events.out.tfevents.1733343140.SocialAIs-Mac-Studio-2.local.3494.1 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Coin/events.out.tfevents.1733343140.SocialAIs-Mac-Studio-2.local.3494.2 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343140/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Wall/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.3
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Wall/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.3 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Wall
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Gem/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.1
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Gem/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.1 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Gem
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Coin/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.2
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Coin/events.out.tfevents.1733344534.SocialAIs-Mac-Studio-2.local.3937.2 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344534/Agent_0_Encounters_Coin
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/events.out.tfevents.1733343163.SocialAIs-Mac-Studio-2.local.3512.0
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/events.out.tfevents.1733343163.SocialAIs-Mac-Studio-2.local.3512.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Wall/events.out.tfevents.1733343163.SocialAIs-Mac-Studio-2.local.3512.3 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Wall
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Gem/events.out.tfevents.1733343163.SocialAIs-Mac-Studio-2.local.3512.1 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Gem
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Coin/events.out.tfevents.1733343163.SocialAIs-Mac-Studio-2.local.3512.2 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343163/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/events.out.tfevents.1733347833.SocialAIs-Mac-Studio-2.local.4796.0 -> res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Bone/events.out.tfevents.1733347834.SocialAIs-Mac-Studio-2.local.4796.3 -> res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Wall/events.out.tfevents.1733347834.SocialAIs-Mac-Studio-2.local.4796.4 -> res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Gem/events.out.tfevents.1733347834.SocialAIs-Mac-Studio-2.local.4796.1 -> res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Coin/events.out.tfevents.1733347834.SocialAIs-Mac-Studio-2.local.4796.2 -> res/old/fixed_punishment_rate_0.0_0.2_1.0_oneAs_size15_3Resources_ambiguity_20241204-16121733347833/Agent_0_Encounters_Coin
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343074/events.out.tfevents.1733343074.SocialAIs-Mac-Studio-2.local.3458.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733343074
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.0 -> res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Wall/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.3
# Processed ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Wall/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.3 -> res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Wall
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Gem/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.1
# Processed ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Gem/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.1 -> res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Gem
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Coin/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.2
# Processed ../runs/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Coin/events.out.tfevents.1733344604.SocialAIs-Mac-Studio-2.local.3967.2 -> res/old/fixed_punishment_rate_1.0_oneAs_size15_3Resources_20241204-15121733344604/Agent_0_Encounters_Coin
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/events.out.tfevents.1733347204.SocialAIs-Mac-Studio-2.local.4628.0 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Wall/events.out.tfevents.1733347204.SocialAIs-Mac-Studio-2.local.4628.3 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Gem/events.out.tfevents.1733347204.SocialAIs-Mac-Studio-2.local.4628.1 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Coin/events.out.tfevents.1733347204.SocialAIs-Mac-Studio-2.local.4628.2 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347204/Agent_0_Encounters_Coin
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344428/events.out.tfevents.1733344428.SocialAIs-Mac-Studio-2.local.3910.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344428
# Data for tag 'Agent_0/Loss' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_vote_against_punishment_data.csv
# Data for tag 'state_punishment_level_avg' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/state_punishment_level_avg_data.csv
# Data for tag 'state_punishment_level_end' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/state_punishment_level_end_data.csv
# Data for tag 'state_punishment_level_init' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/state_punishment_level_init_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/events.out.tfevents.1733347757.SocialAIs-Mac-Studio-2.local.4755.0 -> res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Bone/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Bone/events.out.tfevents.1733347757.SocialAIs-Mac-Studio-2.local.4755.3 -> res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Bone
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Wall/events.out.tfevents.1733347757.SocialAIs-Mac-Studio-2.local.4755.4 -> res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Gem/events.out.tfevents.1733347757.SocialAIs-Mac-Studio-2.local.4755.1 -> res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Coin/events.out.tfevents.1733347757.SocialAIs-Mac-Studio-2.local.4755.2 -> res/old/fixed_punishment_rate_0.0_0.0_0.25_oneAs_size15_3Resources_ambiguity_20241204-16121733347757/Agent_0_Encounters_Coin
# Processed ../runs/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347147/events.out.tfevents.1733347147.SocialAIs-Mac-Studio-2.local.4597.0 -> res/old/fixed_punishment_rate_0.0_0.1_0.5_oneAs_size15_3Resources_ambiguity_20241204-16121733347147
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/events.out.tfevents.1733344649.SocialAIs-Mac-Studio-2.local.3984.0
# Processed ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/events.out.tfevents.1733344649.SocialAIs-Mac-Studio-2.local.3984.0 -> res/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Wall/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.3
# Processed ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Wall/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.3 -> res/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Wall
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Gem/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.1
# Processed ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Gem/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.1 -> res/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Gem
# Skipped corrupted file: ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Coin/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.2
# Processed ../runs/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Coin/events.out.tfevents.1733344650.SocialAIs-Mac-Studio-2.local.3984.2 -> res/old/fixed_punishment_rate_0.25_oneAs_size15_3Resources_20241204-15121733344649/Agent_0_Encounters_Coin
# Processed ../runs/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344403/events.out.tfevents.1733344403.SocialAIs-Mac-Studio-2.local.3875.0 -> res/old/fixed_punishment_rate_0.0_oneAs_size15_3Resources_20241204-15121733344403
# Data for tag 'Agent_0/Loss' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/Epsilon' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Epsilon_data.csv
# Data for tag 'Agent_0/vote_for_punishment' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_vote_for_punishment_data.csv
# Data for tag 'Agent_0/vote_against_punishment' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_vote_against_punishment_data.csv
# Processed ../runs/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/events.out.tfevents.1733413660.SocialAIs-Mac-Studio-2.local.11709.0 -> res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Wall/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Wall/events.out.tfevents.1733413661.SocialAIs-Mac-Studio-2.local.11709.3 -> res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Wall
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Gem/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Gem/events.out.tfevents.1733413661.SocialAIs-Mac-Studio-2.local.11709.1 -> res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Gem
# Data for tag 'Agent_0/Encounters' has been written to res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Coin/Agent_0_Encounters_data.csv
# Processed ../runs/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Coin/events.out.tfevents.1733413661.SocialAIs-Mac-Studio-2.local.11709.2 -> res/control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660/Agent_0_Encounters_Coin

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# reward

# %%
# folders = [
#     # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
#     'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891', 
#     'fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845',
#     'fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747',
#     'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804',

# ]

folders = [
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_2_20241202-17121733176970',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_3_20241202-17121733176981',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_4_20241202-17121733176995',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_5_20241202-17121733177002',
]

folders = ['control_no_punishment_oneAs_no_prediction_size7_maxstep20_2resources_20241205-10121733413660']

collective_rs = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'Reward' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_rs[ixs].append(data['Value'].to_numpy()[:])
collective_rs_ = [np.mean(collective_rs[i], axis=0) for i in range(len(collective_rs))]

# %%
smoothed_collective_rs_ = [rolling_average(d, 500) for d in collective_rs_]
plot_average_trajectory(smoothed_collective_rs_, 'sem', title='reward')

# %%
labels = ['1.0', '0.75,', '0.25', '0.0']
labels = ['1.0', '0.0']
labels = [f'{i}' for i in range(4)]

alpha = 0.2
wsize = 100
for ixs, d in enumerate(collective_rs_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Mean R')
# Out:
# Text(0.5, 1.0, 'Mean R')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500
for i in range(len(labels)):
    for j in range(len(collective_rs[i])):
        axes[i].plot(rolling_average(collective_rs[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Reward')
# Out:
# Text(0.5, 0.98, 'Reward')

# %% [markdown]
# encounter_coins

# %%
# folders = [
#     # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
#     # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
#     'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891', 
#     'fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845',
#     'fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747',
#     'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804',

# ]

folders = [
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_2_20241202-17121733176970',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_3_20241202-17121733176981',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_4_20241202-17121733176995',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_5_20241202-17121733177002',
]
entity_name = 'Coin'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:6200]) # trim if needed

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
collective[0][2].shape
# Out:
# (12000,)

# %%
labels = ['1.0', '0.75,', '0.25', '0.0']
labels = ['1.0', '0.0']
labels = [f'{i}' for i in range(4)]

alpha = 0.2
wsize = 100
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Coin')
# Out:
# Text(0.5, 1.0, 'Coin')

# %%
smoothed_collective_= [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, 'sem', title='coin')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500
for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Coin')
# Out:
# Text(0.5, 0.98, 'Coin')

# %%
folders = [
    # 'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891',
    # 'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585852',
    'fixed_punishment_rate_1.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_20241125-20111732585891', 
    'fixed_punishment_rate_0.75_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638845',
    'fixed_punishment_rate_0.25_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638747',
    'fixed_punishment_rate_0.0_twoAs_extra_percept_v2_higher_harm_gem_has_value_save_model_20241126-11111732638804',

]

folders = [
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_2_20241202-17121733176970',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_3_20241202-17121733176981',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_4_20241202-17121733176995',
    'fixed_punishment_rate_1.0_sixAs_size16_gem_has_value_epsilon0.01_5_20241202-17121733177002',
]

entity_name = 'Gem'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:6200])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
labels = ['1.0', '0.75,', '0.25', '0.0']
labels = ['1.0', '0.0']
labels = [f'{i}' for i in range(4)]

alpha = 0.2
wsize = 100
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Gem')
# Out:
# Text(0.5, 1.0, 'Gem')

# %%
smoothed_collective_= [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, 'sem', title='gem')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500

for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Gem')
# Out:
# Text(0.5, 0.98, 'Gem')
