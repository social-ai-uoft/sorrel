# %%
import tensorflow as tf
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import itertools
from tensorflow.python.framework.errors_impl import DataLossError
from collections import defaultdict
import os, csv
import re
import time

# %%
np.array([[1, 2], [4, 5]])[-2, 1]
# Out:
# np.int64(2)

# %%
def replace_spaces_recursive(directory):
    """
    Recursively replaces spaces in all file names in the given directory and its subdirectories with underscores.
    
    Args:
        directory (str): The root directory to start from.
    
    Returns:
        None
    """
    for root, _, files in os.walk(directory):  # Recursively walk through all directories
        for filename in files:
            old_path = os.path.join(root, filename)  # Full path of the file
            
            if " " in filename:  # Only process files with spaces in the name
                new_filename = filename.replace(" ", "_")  # Replace spaces with underscores
                new_path = os.path.join(root, new_filename)  # New file path
                
                os.rename(old_path, new_path)  # Rename the file
                print(f'Renamed: "{old_path}" → "{new_path}"')

# %%
replace_spaces_recursive('../analysis/res')
# Out:
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v1_20250210-23021739248088/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_fixed_faster_v2_20250205-20021738805787/sum freq_data.csv" → "../analysis/res/debug_fixed_faster_v2_20250205-20021738805787/sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739907962/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_hardcoded_20250212-15021739392944/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-14021739907049/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v2_learned_selection_reset_var_20250215-16021739655112/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_0_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_0_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_1_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_1_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_3/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_3/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_4/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_4/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_3_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_3_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_5_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_5_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_4_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_4_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_3_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_3_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_2_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_2_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_5/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_5/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_4_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_4_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_5_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_5_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_3_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_3_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_1_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_1_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_0_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_0_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_4_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_4_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_5_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_5_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_5_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_5_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_4_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_4_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_0_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_0_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_1_selected/Agent_4_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_4_selection freq_Agent_1_selected/Agent_4_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_5_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_5_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_4_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_4_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_3_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_3_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_2_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_2_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_2_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_2_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_3_selected/Agent_5_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_5_selection freq_Agent_3_selected/Agent_5_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_3_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_0_selection freq_Agent_3_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_4_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_4_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_5_selected/Agent_3_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_3_selection freq_Agent_5_selected/Agent_3_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v3_selection_6agents_20250215-15021739651436/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_fixed_faster_v1_0.01_20250205-21021738808147/sum freq_data.csv" → "../analysis/res/debug_fixed_faster_v1_0.01_20250205-21021738808147/sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_random_20250212-15021739393658/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/multiagent_test_v2_20250212-02021739344561/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# ...
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v1_learning_identity_info_social_comparison_20250212-19021739405711/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/debug_study2_v3_20250218-14021739908366/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-13021739904972/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_2_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_2_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_2/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_2/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_1_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_1_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_0_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_0_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_2_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_2_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_0_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_0_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_1_selected/Agent_1_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_1_selection freq_Agent_1_selected/Agent_1_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_0/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_0/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_1/occurence sum freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/occurence sum freq_Agent_1/occurence_sum_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_2_selected/Agent_0_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_0_selection freq_Agent_2_selected/Agent_0_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_1_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_1_selected/Agent_2_selection_freq_data.csv"
# Renamed: "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_0_selected/Agent_2_selection freq_data.csv" → "../analysis/res/SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847/Agent_2_selection freq_Agent_0_selected/Agent_2_selection_freq_data.csv"

# %% [markdown]
# Preprocessing: Convert tensorboard event files to csv

# %%
def tensorboard_to_csv(event_file, csv_file):
    """
    Convert TensorBoard event file data to a CSV format.

    Args:
        event_file (str): Path to the TensorBoard event file (e.g., events.out.tfevents.xxx).
        csv_file (str): Path where the output CSV file should be saved.
    """
    # Create a list to store the data rows
    data_rows = []
    
    # Use tf.compat.v1 to access the summary_iterator in TensorFlow 2.x
    for e in tf.compat.v1.train.summary_iterator(event_file):
        for v in e.summary.value:
            # Only consider scalar summaries
            if v.HasField('simple_value'):
                tag = v.tag
                value = v.simple_value
                step = e.step
                data_rows.append([step, tag, value])
    
    # Write the extracted data into a CSV file
    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['Step', 'Tag', 'Value'])
        # Write the data rows
        writer.writerows(data_rows)
    
    print(f"Data from {event_file} has been written to {csv_file}")

# %%
def tensorboard_to_separate_csv(event_file, output_dir):
    """
    Convert TensorBoard event file data to separate CSV files for each tag.
    """
    tag_data = defaultdict(list)

    try:
        for e in tf.compat.v1.train.summary_iterator(event_file):
            try:
                # Process individual records
                for v in e.summary.value:
                    if v.HasField('simple_value'):
                        tag = v.tag
                        value = v.simple_value
                        step = e.step
                        tag_data[tag].append([step, value])
            except Exception as record_error:
                # Log a warning and skip problematic records
                print(f"Skipped a corrupt record in file: {event_file}")
    except DataLossError:
        # Log and continue for files with partial writes
        print(f"Encountered DataLossError. Possibly due to incomplete writes in file: {event_file}")

    # Save tag data to CSV files
    for tag, data_rows in tag_data.items():
        filename = f"{output_dir}/{tag.replace('/', '_')}_data.csv"
        with open(filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Step', 'Value'])
            writer.writerows(data_rows)
        print(f"Data for tag '{tag}' has been written to {filename}")

# %%
def is_file_stable(file_path, wait_time=1.0):
    initial_size = os.path.getsize(file_path)
    time.sleep(wait_time)
    final_size = os.path.getsize(file_path)
    return initial_size == final_size

def process_tensorboard_results(parent_dir, output_parent_dir):
    """
    Loop through all subdirectories of a parent directory, process TensorBoard files,
    and save results to a corresponding directory structure.

    Args:
        parent_dir (str): Parent directory containing TensorBoard event files.
        output_parent_dir (str): Parent directory where CSV files should be saved.
    """
    for root, dirs, files in os.walk(parent_dir):
        for file in files:
            if "tfevents" in file:  # Check if the file is a TensorBoard event file
                event_file = os.path.join(root, file)
                relative_path = os.path.relpath(root, parent_dir)
                output_dir = os.path.join(output_parent_dir, relative_path)
                os.makedirs(output_dir, exist_ok=True)

                # Check if the file is stable
                if not is_file_stable(event_file):
                    print(f"File is still being written: {event_file}, skipping.")
                    continue

                try:
                    tensorboard_to_separate_csv(event_file, output_dir)
                    print(f"Processed {event_file} -> {output_dir}")
                except Exception as e:
                    print(f"Failed to process {event_file}: {e}")

def process_tensorboard_results(parent_dir, 
                                output_parent_dir, 
                                skip_existing=True, 
                                skip_existing_by_time=False,
                                skip_unstable=False
                                ):
    """
    Loop through all subdirectories of a parent directory, process TensorBoard files,
    and save results to a corresponding directory structure, skipping already processed files.

    Args:
        parent_dir (str): Parent directory containing TensorBoard event files.
        output_parent_dir (str): Parent directory where CSV files should be saved.
    """
    for root, dirs, files in os.walk(parent_dir):
        for file in files:
            if "tfevents" in file:  # Check if the file is a TensorBoard event file
                event_file = os.path.join(root, file)
                relative_path = os.path.relpath(root, parent_dir)
                output_dir = os.path.join(output_parent_dir, relative_path)
                
                # Skip processing if output file already exists
                if skip_existing:
                    if os.path.exists(output_dir):
                        print(f"Skipping already processed file: {event_file}")
                        continue

                if skip_existing_by_time:
                    N = 4  # Time filter in hours
                    # Get current time
                    now = time.time()
                    mod_time = os.path.getmtime(event_file)
                    # Check if the file was modified in the last N hours
                    if (now - mod_time) > N * 3600:
                        print(f"Skipping file modified more than {N} hours ago: {event_file}")
                        continue
                    
                os.makedirs(output_dir, exist_ok=True)

                # Check if the file is stable
                if skip_unstable:
                    if not is_file_stable(event_file):
                        print(f"File is still being written: {event_file}, skipping.")
                        continue

                try:
                    tensorboard_to_separate_csv(event_file, output_dir)
                    print(f"Processed {event_file} -> {output_dir}")
                except Exception as e:
                    print(f"Failed to process {event_file}: {e}")

# %%
parent_dir = '../runs'
output_dir = 'res'
process_tensorboard_results(parent_dir, output_dir, skip_existing=False, skip_existing_by_time=False, skip_unstable=False)
# Out:
# Data for tag 'Agent_1/act_match_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_act_match_pref_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/dominant_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_dominant_pref_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_entropy_data.csv
# Data for tag 'Agent_1/selected_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selected_partner_entropy_data.csv
# Data for tag 'Agent_1/presented_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_presented_partner_entropy_data.csv
# Data for tag 'Agent_1/select_more_entropic_one' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_select_more_entropic_one_data.csv
# Data for tag 'Agent_1/selection_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_sum_freq_data.csv
# Data for tag 'Agent_1/max_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_max_pref_data.csv
# Data for tag 'Agent_1/bach_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_bach_preference_data.csv
# Data for tag 'Agent_1/stravinsky_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_stravinsky_preference_data.csv
# Data for tag 'Agent_2/act_match_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_act_match_pref_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/dominant_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_dominant_pref_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_entropy_data.csv
# Data for tag 'Agent_2/selected_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selected_partner_entropy_data.csv
# Data for tag 'Agent_2/presented_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_presented_partner_entropy_data.csv
# Data for tag 'Agent_2/select_more_entropic_one' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_select_more_entropic_one_data.csv
# Data for tag 'Agent_2/selection_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_sum_freq_data.csv
# Data for tag 'Agent_2/max_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_max_pref_data.csv
# Data for tag 'Agent_2/bach_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_bach_preference_data.csv
# Data for tag 'Agent_2/stravinsky_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_stravinsky_preference_data.csv
# Data for tag 'same_choices' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/same_choices_data.csv
# Data for tag 'choice_matches_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/choice_matches_preference_data.csv
# Data for tag 'Agent_0/act_match_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_act_match_pref_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/dominant_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_dominant_pref_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_entropy_data.csv
# Data for tag 'Agent_0/selected_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selected_partner_entropy_data.csv
# Data for tag 'Agent_0/presented_partner_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_presented_partner_entropy_data.csv
# Data for tag 'Agent_0/select_more_entropic_one' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_select_more_entropic_one_data.csv
# Data for tag 'Agent_0/selection_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_sum_freq_data.csv
# Data for tag 'Agent_0/max_pref' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_max_pref_data.csv
# Data for tag 'Agent_0/bach_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_bach_preference_data.csv
# Data for tag 'Agent_0/stravinsky_preference' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_stravinsky_preference_data.csv
# Data for tag 'diversity' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/diversity_data.csv
# Data for tag 'population_mean_entropy' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/population_mean_entropy_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/events.out.tfevents.1742064101.Yikais-Mac-mini.local.17122.0 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101
# Data for tag 'Agent_0/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_2_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.25 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_2_selected
# Data for tag 'Agent_1/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_2_selected/Agent_1_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.9 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_2_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_0_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.12 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_0_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_1_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.13 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_1_selected
# Data for tag 'Agent_0/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_2_selected/Agent_0_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.31 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_2_selected
# Data for tag 'Agent_2/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_1_selected/Agent_2_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.19 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_1_selected
# Data for tag 'Agent_2/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_0_selected/Agent_2_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.18 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_0_selected
# Data for tag 'Agent_2/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_0_selected/Agent_2_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.15 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_0_selected
# Data for tag 'Agent_2/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_1_selected/Agent_2_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.16 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_1_selected
# Data for tag 'Agent_2/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_0/Agent_2_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_0/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.21 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_0
# Data for tag 'Agent_2/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_1/Agent_2_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_1/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.22 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_action_freq_action_1
# Data for tag 'Agent_1/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_1_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.2 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_0_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.1 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_2_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.6 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_2_selected
# Data for tag 'occurence_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_0/occurence_sum_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_0/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.36 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_0
# Data for tag 'Agent_0/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_3/Agent_0_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_3/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.35 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_3
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_2_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.28 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_2/Agent_0_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_2/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.34 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_2
# Data for tag 'occurence_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_1/occurence_sum_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_1/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.37 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_1
# Data for tag 'Agent_2/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_2_selected/Agent_2_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.20 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_B_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_1_selected/Agent_0_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.30 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_1_selected
# Data for tag 'Agent_0/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_0_selected/Agent_0_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.29 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_B_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_1/Agent_1_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_1/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.11 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_1
# Data for tag 'Agent_1/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_0/Agent_1_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_0/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.10 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_action_freq_action_0
# Data for tag 'Agent_0/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_0_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.23 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_1_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.24 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_1_selected/Agent_1_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.8 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_1_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_2_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.14 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_selection_freq_Agent_2_selected
# Data for tag 'Agent_1/decider_B_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_0_selected/Agent_1_decider_B_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.7 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_B_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_0_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.26 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_1_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.27 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_decider_A_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_0_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_0_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.4 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_2_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.3 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_selection_freq_Agent_2_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_1_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_1_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.5 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_1_decider_A_selection_freq_Agent_1_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_0/Agent_0_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_0/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.32 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_0
# Data for tag 'Agent_2/decider_A_selection_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_2_selected/Agent_2_decider_A_selection_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.17 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_2_decider_A_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_1/Agent_0_action_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_1/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.33 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/Agent_0_action_freq_action_1
# Data for tag 'occurence_sum_freq' has been written to res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_2/occurence_sum_freq_data.csv
# Processed ../runs/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_2/events.out.tfevents.1742064102.Yikais-Mac-mini.local.17122.38 -> res/test_neutral_rm_partner_free_choice_vary_Freq_40_random_sym_cost0.0_v0_seed1_20250315-14031742064101/occurence_sum_freq_Agent_2
# Encountered DataLossError. Possibly due to incomplete writes in file: ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.0
# Data for tag 'Agent_1/act_match_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_act_match_pref_data.csv
# Data for tag 'Agent_1/Loss' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_Loss_data.csv
# Data for tag 'Agent_1/dominant_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_dominant_pref_data.csv
# Data for tag 'Agent_1/Reward' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_Reward_data.csv
# Data for tag 'Agent_1/entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_entropy_data.csv
# Data for tag 'Agent_1/selected_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selected_partner_entropy_data.csv
# Data for tag 'Agent_1/presented_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_presented_partner_entropy_data.csv
# Data for tag 'Agent_1/select_more_entropic_one' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_select_more_entropic_one_data.csv
# Data for tag 'Agent_1/selection_sum_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_sum_freq_data.csv
# Data for tag 'Agent_1/max_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_max_pref_data.csv
# Data for tag 'Agent_1/bach_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_bach_preference_data.csv
# Data for tag 'Agent_1/stravinsky_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_stravinsky_preference_data.csv
# Data for tag 'Agent_2/act_match_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_act_match_pref_data.csv
# Data for tag 'Agent_2/Loss' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_Loss_data.csv
# Data for tag 'Agent_2/dominant_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_dominant_pref_data.csv
# Data for tag 'Agent_2/Reward' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_Reward_data.csv
# Data for tag 'Agent_2/entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_entropy_data.csv
# Data for tag 'Agent_2/selected_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selected_partner_entropy_data.csv
# Data for tag 'Agent_2/presented_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_presented_partner_entropy_data.csv
# Data for tag 'Agent_2/select_more_entropic_one' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_select_more_entropic_one_data.csv
# Data for tag 'Agent_2/selection_sum_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_sum_freq_data.csv
# Data for tag 'Agent_2/max_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_max_pref_data.csv
# Data for tag 'Agent_2/bach_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_bach_preference_data.csv
# Data for tag 'Agent_2/stravinsky_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_stravinsky_preference_data.csv
# Data for tag 'same_choices' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/same_choices_data.csv
# Data for tag 'choice_matches_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/choice_matches_preference_data.csv
# Data for tag 'Agent_0/act_match_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_act_match_pref_data.csv
# Data for tag 'Agent_0/Loss' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_Loss_data.csv
# Data for tag 'Agent_0/dominant_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_dominant_pref_data.csv
# Data for tag 'Agent_0/Reward' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_Reward_data.csv
# Data for tag 'Agent_0/entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_entropy_data.csv
# Data for tag 'Agent_0/selected_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selected_partner_entropy_data.csv
# Data for tag 'Agent_0/presented_partner_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_presented_partner_entropy_data.csv
# Data for tag 'Agent_0/select_more_entropic_one' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_select_more_entropic_one_data.csv
# Data for tag 'Agent_0/selection_sum_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_sum_freq_data.csv
# Data for tag 'Agent_0/max_pref' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_max_pref_data.csv
# Data for tag 'Agent_0/bach_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_bach_preference_data.csv
# Data for tag 'Agent_0/stravinsky_preference' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_stravinsky_preference_data.csv
# Data for tag 'diversity' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/diversity_data.csv
# Data for tag 'population_mean_entropy' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/population_mean_entropy_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.0 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388
# Data for tag 'Agent_0/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_2_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_2_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.13 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_2_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_0_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_0_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.6 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_0_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_1_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_1_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.7 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_selection_freq_Agent_1_selected
# Data for tag 'Agent_2/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_0/Agent_2_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_0/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.9 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_0
# Data for tag 'Agent_2/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_1/Agent_2_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_1/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.10 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_2_action_freq_action_1
# Data for tag 'Agent_1/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_1_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_1_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.2 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_0_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_0_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.1 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_selection_freq_Agent_0_selected
# Data for tag 'occurence_sum_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_0/occurence_sum_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_0/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.18 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_0
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_3/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_3/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.17 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_3
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_2/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_2/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.16 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_action_freq_action_2
# Data for tag 'occurence_sum_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_1/occurence_sum_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_1/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.19 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/occurence_sum_freq_Agent_1
# Data for tag 'Agent_1/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_1/Agent_1_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_1/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.5 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_1
# Data for tag 'Agent_1/action_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_0/Agent_1_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_0/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.4 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_1_action_freq_action_0
# Data for tag 'Agent_0/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_0_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_0_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.11 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/selection_freq' has been written to res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_1_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_1_selected/events.out.tfevents.1741983388.Yikais-Mac-mini.local.1212.12 -> res/test_diff_rm_partner_free_choice_nonvary_learned_sym_cost0.0_v0_seed1_20250314-16031741983388/Agent_0_selection_freq_Agent_1_selected
# ...
# Data for tag 'Agent_1/selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_0_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.1 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_2_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.6 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_2_selected
# Data for tag 'occurence_sum_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_0/occurence_sum_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_0/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.36 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_0
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_3/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_3/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.35 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_3
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_2_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.28 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_2/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_2/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.34 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_2
# Data for tag 'occurence_sum_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_1/occurence_sum_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_1/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.37 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_1
# Data for tag 'Agent_2/decider_B_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_B_selection_freq_Agent_2_selected/Agent_2_decider_B_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_B_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.20 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_B_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/decider_B_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_1_selected/Agent_0_decider_B_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_1_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.30 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_1_selected
# Data for tag 'Agent_0/decider_B_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_0_selected/Agent_0_decider_B_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.29 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_B_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_1/Agent_1_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_1/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.11 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_1
# Data for tag 'Agent_1/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_0/Agent_1_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_0/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.10 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_action_freq_action_0
# Data for tag 'Agent_0/selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_0_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.23 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_1_selected/Agent_0_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_1_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.24 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/decider_B_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_1_selected/Agent_1_decider_B_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_1_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.8 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_1_selected
# Data for tag 'Agent_2/selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_selection_freq_Agent_2_selected/Agent_2_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.14 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_selection_freq_Agent_2_selected
# Data for tag 'Agent_1/decider_B_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_0_selected/Agent_1_decider_B_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.7 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_B_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_0_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.26 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_0_selected
# Data for tag 'Agent_0/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_1_selected/Agent_0_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_1_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.27 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_decider_A_selection_freq_Agent_1_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_0_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_0_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.4 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_0_selected
# Data for tag 'Agent_1/selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_2_selected/Agent_1_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.3 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_selection_freq_Agent_2_selected
# Data for tag 'Agent_1/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_1_selected/Agent_1_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_1_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.5 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_1_decider_A_selection_freq_Agent_1_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_0/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_0/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.32 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_0
# Data for tag 'Agent_2/decider_A_selection_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_A_selection_freq_Agent_2_selected/Agent_2_decider_A_selection_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_A_selection_freq_Agent_2_selected/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.17 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_2_decider_A_selection_freq_Agent_2_selected
# Data for tag 'Agent_0/action_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_1/Agent_0_action_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_1/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.33 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/Agent_0_action_freq_action_1
# Data for tag 'occurence_sum_freq' has been written to res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_2/occurence_sum_freq_data.csv
# Processed ../runs/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_2/events.out.tfevents.1741985101.Yikais-Mac-mini.local.3085.38 -> res/test_diff_rm_partner_free_choice_vary_Freq_40_learned_sym_cost0.0_v0_seed1_20250314-16031741985101/occurence_sum_freq_Agent_2

# %% [markdown]
# Utils: Plotting and Analysis

# %%
def spectral_centroid(x, samplerate=1):
    magnitudes = np.abs(np.fft.rfft(x)) # magnitudes of positive frequencies
    length = len(x)
    freqs = np.abs(np.fft.fftfreq(length, 1.0/samplerate)[:length//2+1]) # positive frequencies
    return np.sum(magnitudes*freqs) / np.sum(magnitudes)

# %%
def count_threshold_crossings(trajectory, threshold):
    """
    Count the number of times a trajectory crosses a given threshold.
    
    Parameters:
        trajectory (array-like): The sequence of values.
        threshold (float): The y-value threshold to check crossings against.
        
    Returns:
        total_crossings (int): Number of total crossings (upward + downward).
        upward_crossings (int): Number of times it crossed from below to above.
        downward_crossings (int): Number of times it crossed from above to below.
    """
    trajectory = np.asarray(trajectory)
    above = trajectory > threshold

    total_crossings = np.count_nonzero(above[1:] != above[:-1])
    upward_crossings = np.count_nonzero((trajectory[:-1] < threshold) & (trajectory[1:] >= threshold))
    downward_crossings = np.count_nonzero((trajectory[:-1] >= threshold) & (trajectory[1:] < threshold))

    return total_crossings, upward_crossings, downward_crossings

# %%
def exponential_moving_average(data, alpha):
    """
    Calculate the exponential moving average (EMA) of a 1D array.

    Args:
        data (array-like): The input data.
        alpha (float): The smoothing factor (0 < alpha <= 1).

    Returns:
        numpy.ndarray: The EMA values.
    """
    if not (0 < alpha <= 1):
        raise ValueError("Alpha must be between 0 and 1.")

    ema = [data[0]]  # Initialize EMA with the first data point
    for i in range(1, len(data)):
        ema.append(alpha * data[i] + (1 - alpha) * ema[-1])
    return np.array(ema)


def rolling_average(data, window_size):
    """
    Calculate the rolling average of a 1D array.

    Args:
        data (array-like): The input data.
        window_size (int): The size of the rolling window.

    Returns:
        numpy.ndarray: The rolling average values.
    """
    if window_size < 1:
        raise ValueError("Window size must be at least 1.")
    if len(data) < window_size:
        raise ValueError("Data length must be at least equal to the window size.")
    
    # Use np.convolve for efficient computation
    weights = np.ones(window_size) / window_size
    return np.convolve(data, weights, mode='valid')

def plot_average_trajectory(time_series, error_type='std', time_points=None, xlabel='Time', ylabel='Value', title='Average Trajectory'):
    """
    Plots the average trajectory of a set of time series with error bars.

    Parameters:
    - time_series (2D array-like): A set of time series, shape (n_series, n_time_points).
    - error_type (str): Either 'std' for standard deviation or 'sem' for standard error.
    - time_points (1D array-like, optional): Time points corresponding to the time series. Defaults to indices.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - title (str): Title of the plot.
    """
    time_series = np.array(time_series)
    if time_points is None:
        time_points = np.arange(time_series.shape[1])
    else:
        time_points = np.array(time_points)
    
    if time_series.shape[1] != len(time_points):
        raise ValueError("Length of time_points must match the number of columns in time_series.")
    
    # Compute average and error
    mean_trajectory = np.mean(time_series, axis=0)
    if error_type == 'std':
        error = np.std(time_series, axis=0)
    elif error_type == 'sem':
        error = np.std(time_series, axis=0) / np.sqrt(time_series.shape[0])
    else:
        raise ValueError("error_type must be 'std' or 'sem'.")
    
    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(time_points, mean_trajectory, label='Mean Trajectory', color='blue')
    plt.fill_between(time_points, mean_trajectory - error, mean_trajectory + error, alpha=0.3, color='blue', label='Error')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(False)
    plt.show()

def trim_and_calculate_mean(array_list):
    # Find the minimum length among all arrays
    min_length = min(len(arr) for arr in array_list)
    
    # Trim each array to the minimum length
    trimmed_arrays = [arr[:min_length] for arr in array_list]
    
    # Convert to a NumPy array for vectorized mean calculation
    trimmed_arrays = np.array(trimmed_arrays)
    
    return trimmed_arrays

# %%
import numpy as np
from scipy.stats import ttest_ind, mannwhitneyu

def compare_binned_time_series(data_group1, data_group2, num_bins=10, test_func=ttest_ind, **test_kwargs):
    """
    Compare two groups' time-series data by dividing the time course into bins,
    averaging values in each bin, and performing a specified statistical test.

    Args:
        data_group1 (list of lists or np.array): Time-series data for group 1 (each row is an instance).
        data_group2 (list of lists or np.array): Time-series data for group 2 (each row is an instance).
        num_bins (int): Number of bins to divide the time course.
        test_func (callable): Statistical test function (default: t-test). 
                              Must accept two arrays and return a statistic and p-value.
        **test_kwargs: Additional keyword arguments to pass to the statistical test.

    Returns:
        dict: Contains test statistics, p-values, and Bonferroni-corrected significance for each bin.
    """
    # Convert to NumPy arrays
    data_group1 = np.array(data_group1)
    data_group2 = np.array(data_group2)

    # Ensure both groups have the same number of time steps
    assert data_group1.shape[1] == data_group2.shape[1], "Mismatched time steps"

    # Define bin edges
    num_timesteps = data_group1.shape[1]
    bin_edges = np.linspace(0, num_timesteps, num_bins + 1, dtype=int)

    results = {}
    alpha_corrected = 0.05 / num_bins  # Bonferroni correction

    for i in range(num_bins):
        start, end = bin_edges[i], bin_edges[i+1]

        # Compute mean values in the bin for each instance
        mean_group1 = data_group1[:, start:end].mean(axis=1)
        mean_group2 = data_group2[:, start:end].mean(axis=1)

        # Perform the specified test
        test_stat, p_val = test_func(mean_group1, mean_group2, **test_kwargs)

        # Store results
        results[f"Bin {i+1}"] = {
            "test_statistic": test_stat,
            "p-value": p_val,
            "threshold after Bonferroni correction": alpha_corrected,
            "significant (Bonferroni)": p_val < alpha_corrected
        }

    return results

# %%
def read_group_data_with_specified_tag(folder, tag_keyword, excluded_keyword, has_child_dir=False):
    """
    Read group data from CSV files with a specified tag in the given folder.

    Args:
        folder (str): The folder containing the CSV files.
        tag (str): The tag to search for in the CSV file names.
        has_child_dir (bool): Whether the CSV files are in subdirectories.

    Returns:
        dict: A dictionary containing the data read from the CSV files.
    """
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    group_data = []

    data = None 

    if has_child_dir:
        for file in files:
            if tag_keyword in file:
                sub_dir = os.path.join(parent_dir, file)            
                file = os.listdir(sub_dir)[0]
                data = pd.read_csv(os.path.join(sub_dir, file))
                group_data.append(np.nan_to_num(data['Value'].to_numpy(), 0))
    else:
        for file in files:
            if (tag_keyword in file) and (excluded_keyword not in file):
                data = pd.read_csv(os.path.join(parent_dir, file))
                group_data.append(np.nan_to_num(data['Value'].to_numpy(), 0))

    assert data is not None, f"No file with tag '{tag_keyword}' found in folder '{folder}'."
    
    return group_data

# %%
def plot_data_per_condition(folders, wsize, tag_keyword, excluded_keyword, labels, has_child_dir, ):
    """
    Plot the data for each condition.
    """
    collective_d = [[] for _ in range(len(folders))]
    for ixs, folder in enumerate(folders):
        collective_d[ixs] = read_group_data_with_specified_tag(folder, tag_keyword, excluded_keyword, has_child_dir)
    collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]
    # print(collective_d)

    # plot
    # alpha = 0.99
    fig, axes0 = plt.subplots(1, 1, figsize=(4,4))
    wsize = wsize
    for ixs, d in enumerate(collective_d_avg):
        # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
        plt.plot(rolling_average(d, wsize), label=labels[ixs])
        print(labels[ixs], np.mean(d))
    plt.legend()
    plt.title(f'Mean {tag_keyword}')
    # print(collective_d_avg)

    fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
    wsize = wsize
    for i in range(len(labels)):
        print(len(collective_d[i]))
        for j in range(len(collective_d[i])):
            axes[i].plot(rolling_average(collective_d[i][j], wsize))
        axes[i].set_title(labels[i])
    plt.suptitle(f'Individual {tag_keyword}')

# %% [markdown]
# test

# %%
folders = [
    'SB_task_v2_learned_selection_iqn_20250214-16021739569532',
    'SB_task_v2_random_iqn_20250215-17021739657418',
]
folders = [
    'SB_task_v2_learned_selection_20250214-11021739550211',
    'SB_task_v2_random_20250214-11021739550153',
]
folders = [
    'SB_task_v3_learned_selection_reset_var_high_20250217-21021739844258',
    'SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847'
]
    
labels = ['Selection lr 0.1', 'Selection lr 0.6']
plot_data_per_condition(folders, 100, 'variability', 'partner', labels, False)
# Out:
# Selection lr 0.1 0.5740978753061197
# Selection lr 0.6 0.38509422023639084
# 4
# 4

# %%
import numpy as np

arr = np.array([[1, 2], [2, 3]])
flipped = np.flip(arr, axis=1)  # flip along rows (vertically)
print(flipped)
# Out:
# [[2 1]
#  [3 2]]

# %% [markdown]
# reward

# %%
# folders = [
#     'SB_task_v3_learned_selection_reset_var_high_20250217-21021739844258',
#     'SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847'
# ]
# folders = [
#     'SB_task_v3_learned_selection_reset_var_high_0.6_20250217-21021739844847',
#     'SB_task_v3_random_reset_var_high_0.6_with_self_var_with_partner_var_20250218-11021739897094'
# ]

folders = [
    'test_marl_learned_sym_cost0.0_dynamic_sampling_weights_test_rmV3_action7_free_choice_beforehand_seed1_20250315-15031742068042',
    'test_marl_random_sym_cost0.0_dynamic_sampling_weights_test_rmV3_action7_free_choice_beforehand_seed1_20250315-15031742068003',
]

# folders = [
#     'test_multiple_deciders_learned_sym_cost0.1_VarFreq_10_20250306-11031741279795',
#     'test_multiple_deciders_random_sym_cost0.1_VarFreq_10_20250306-11031741279823'
# ]

folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
# folders = [
#      'test_opposite_rm_partner_free_choice_multi_decider_nonvary_learned_v1_seed2_20250316-20031742173147',
#     'test_opposite_rm_partner_free_choice_multi_decider_nonvary_random_v1_seed2_20250316-20031742173179'

# ]       

collective_rs = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'Reward' in f:
            if 'Agent_0' not in f:
                data = pd.read_csv(os.path.join(parent_dir, f))
                collective_rs[ixs].append(data['Value'].to_numpy()[:])
collective_rs_avg = [np.mean(trim_and_calculate_mean(collective_rs[i]), axis=0) for i in range(len(collective_rs))]

# %%
# combine the data from different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'Reward'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    data = pd.read_csv(sub_dir)

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_rs_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
collective_rs
# Out:
# [[array([ 6., 10.,  5., ..., 21., 33., 42.]),
#   array([  5.,   0.,   0., ..., 126.,  72.,  94.]),
#   array([  5.,  25.,  10., ..., 143.,  63.,  96.]),
#   array([ 5.,  5., 10., ..., 65., 60., 99.]),
#   array([  0.,   0.,   5., ..., 108., 109.,  74.]),
#   array([11., 20., 20., ..., 47., 50., 80.])],
#  [array([ 0.,  6., 10., ..., 83., 96., 78.]),
#   array([ 0.,  9.,  0., ..., 63., 66., 80.]),
#   array([ 9., 16.,  5., ..., 86., 93., 45.]),
#   array([  0.,  18.,   5., ...,  45.,  57., 102.]),
#   array([ 0., 10.,  0., ..., 79., 78., 65.]),
#   array([ 6.,  0.,  0., ..., 58., 72., 68.])]]

# %%
# partner pool avg r
labels = ['Selection lr 0.1', 'Selection lr 0.6']
labels = ['partner_selection', 'random_selection']
# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_rs_avg):
    # plt.plot(exponential_moving_average(d, 0.1), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs], alpha=0.6)
plt.legend()
plt.title('partner R')
# Out:
# Text(0.5, 1.0, 'partner R')

# %%
labels = ['Selection lr 0.1', 'Selection lr 0.6']
labels = ['partner_selection', 'random_selection']
# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_rs_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs], alpha=0.6)
plt.legend()
plt.title('decider R')
# Out:
# Text(0.5, 1.0, 'decider R')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 400
for i in range(len(labels)):
    for j in range(len(collective_rs[i])):
        axes[i].plot(rolling_average(collective_rs[i][j], wsize), label=j)
    axes[i].set_title(labels[i])
    # axes[i].legend()
plt.suptitle('Reward')
# Out:
# Text(0.5, 0.98, 'Reward')

# %%
import numpy as np
arr = np.array([1., 0.])
result = np.repeat(arr[np.newaxis, :], repeats=2, axis=0)
result
# Out:
# array([[1., 0.],
#        [1., 0.]])

# %% [markdown]
# Variability

# %%
folders = [
    'sanity_check_four_trainable_learned_selection_with_reset_varydecider_len10_20250224-21021740449358',
    'sanity_check_four_trainable_random_selection_with_reset_varydecider_len10_20250224-21021740449346'
]
folders = [
    'test_multiple_deciders_learned_sym_cost0.1_VarFreq_2_20250306-12031741281754',
    'test_multiple_deciders_random_sym_cost0.1_VarFreq_2_20250306-12031741281724',
]
folders = [
    'test_marl_learned_sym_cost0.0_dynamic_sampling_weights_test_rmV3_action7_free_choice_beforehand_seed1_20250315-15031742068042',
    'test_marl_random_sym_cost0.0_dynamic_sampling_weights_test_rmV3_action7_free_choice_beforehand_seed1_20250315-15031742068003',
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        pattern = r"^Agent_\d+_entropy_data.csv$"
        if bool(re.match(pattern, f)):
            if 'Agent_0' not in f:
                data = pd.read_csv(os.path.join(parent_dir, f))
                collective_d[ixs].append(data['Value'].to_numpy()[:])
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 len(collective_d[2])
#
# IndexError: list index out of range

# %%
labels = ['simple learning', 'simple random', 'selection', 'random']
labels = ['partner selection', 'random selection']
# labels = ['partner selection w/o var information', 'random selection']

# labels = ['Selection lr 0.1', 'Selection lr 0.6']

# alpha = 0.99
wsize = 500
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, 1), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs], alpha=0.6)
    # plt.plot(d)

    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('Mean Entropy')

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500
colors = ['green', 'purple']
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize), alpha=0.6, color=colors[j])
    axes[i].set_title(labels[i])
plt.suptitle('Entropy')
# Out:
# partner selection nan
# random selection nan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 23
#      21 for i in range(len(labels)):
#      22     for j in range(len(collective_d[i])):
# ---> 23         axes[i].plot(rolling_average(collective_d[i][j], wsize), alpha=0.6, color=colors[j])
#      24     axes[i].set_title(labels[i])
#      25 plt.suptitle('Entropy')
#
# IndexError: list index out of range

# %%
folders = [
    'multi_partners_learned_selection_without_partner_preference_20250223-15021740343749',
    'multi_partners_random_selection_without_partner_preference_20250222-23021740284025'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        pattern = r"^Agent_0_action_freq_action_/d$"
        # if bool(re.match(pattern, f)):
        if f.startswith('Agent_0_action_freq_action_'):
            sub_dir = os.path.join(parent_dir, f)
            sub_file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, sub_file))
            collective_d[ixs].append(data['Value'].to_numpy()[:])
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('action_selection_freq')
# Out:
# Text(0.5, 0.98, 'action_selection_freq')

# %% [markdown]
# bach pref & number of crossings

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_rmV2_action7_20250312-16031741812222',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_rmV2_action7_20250312-16031741812252'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        pattern = r"^Agent_\d+_bach_preference_data.csv$"
        if bool(re.match(pattern, f)):
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(data['Value'].to_numpy()[10000:300000])
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
# spectral centroid analysis

spectral_centroid_res = [[], []]
for ixs, condition_d in enumerate(collective_d):
    for d in condition_d:
        spectral_centroid_res[ixs].append(float(spectral_centroid(d)))

# %%
np.mean(spectral_centroid_res, axis=1)
# Out:
# array([0.03911013, 0.02341008])

# %%
res = [[], []]
for ixs, condition_d in enumerate(collective_d):
    for d in condition_d:
        n_crossings = count_threshold_crossings(d, 0.5)
        res[ixs].append(n_crossings[0])

# %%
res = [[[] for _ in range(6)], [[] for _ in range(6)]]
for ixs, condition_d in enumerate(collective_d):
    for ixs_a, d in enumerate(condition_d):
        for i in range(len(d)-100):
            n_crossings = count_threshold_crossings(d[i:i+100], 0.5)
            res[ixs][ixs_a].append(n_crossings[0])

# %%
len(res[1][1])
# Out:
# 402800

# %%
res_ = np.mean(np.array(res), axis=1)
res_.shape
# Out:
# (2, 289900)

# %%
for val in res_:
    plt.plot(rolling_average(val, 1000))

# %%
np.mean(res, axis=1)
# Out:
# array([244.        , 283.83333333])

# %%
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 100
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('bach pref')

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('bach pref')
# Out:
# selection 0.45225911686611914
# random 0.5080188972493228
# Text(0.5, 0.98, 'bach pref')

# %% [markdown]
# preference type

# %%
folders = [
    'sanity_check_four_trainable_learned_selection_with_reset_varydecider_len10_20250224-21021740449358',
    'sanity_check_four_trainable_random_selection_with_reset_varydecider_len10_20250224-21021740449346'
]
# folders = [
#     'sanity_check_two_trainable_learned_selection_with_reset_fixeddecider_len10_20250224-21021740449783',
#     'sanity_check_two_trainable_random_selection_with_reset_fixeddecider_len10_20250224-21021740449767',
# ]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        pattern = r"^Agent_\d+_dominant_pref_data.csv$"
        if bool(re.match(pattern, f)):
            if 'Agent_0' not in f:
                data = pd.read_csv(os.path.join(parent_dir, f))
                collective_d[ixs].append(data['Value'].to_numpy()[:])
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
plt.plot(rolling_average(collective_d[0][1], wsize))

# %%
labels = ['partner selection', 'random selection']
choice_labels = ['Bach', 'Stravinsky']

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(collective_d)):
    axes[i].set_title(choice_labels[i])
    for j in range(len(labels)):
        axes[i].plot(rolling_average(collective_d[j][i], wsize), label=labels[j])
        
plt.legend()
plt.suptitle('dominant_preference_type')
# Out:
# Text(0.5, 0.98, 'dominant_preference_type')

# %%
labels = ['partner selection', 'random selection']

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('main_preference_type')
# Out:
# Text(0.5, 0.98, 'main_preference_type')

# %% [markdown]
# max preference val

# %%
folders = [
    'sanity_check_four_trainable_learned_selection_with_reset_varydecider_len10_20250224-21021740449358',
    'sanity_check_four_trainable_random_selection_with_reset_varydecider_len10_20250224-21021740449346'
]
# folders = [
#     'sanity_check_two_trainable_learned_selection_with_reset_fixeddecider_len10_20250224-21021740449783',
#     'sanity_check_two_trainable_random_selection_with_reset_fixeddecider_len10_20250224-21021740449767',
# ]
folders = [
    'test_multiple_deciders_learned_sym_cost0.1_VarFreq_2_20250306-12031741281754',
    'test_multiple_deciders_random_sym_cost0.1_VarFreq_2_20250306-12031741281724',
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        pattern = r"^Agent_\d+_bach_preference_data.csv$"
        if bool(re.match(pattern, f)):
            if 'Agent_0' not in f:
                data = pd.read_csv(os.path.join(parent_dir, f))
                collective_d[ixs].append(data['Value'].to_numpy()[:])
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 100
colors = ['green', 'purple']
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize), alpha=0.6, color=colors[j])
    axes[i].set_title(labels[i])
plt.suptitle('Bach preference')
# Out:
# Text(0.5, 0.98, 'Bach preference')

# %%
len(collective_d[0])
# Out:
# 2

# %%
labels = ['partner selection', 'random selection']
choice_labels = ['Bach', 'Stravinsky']

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(collective_d)):
    axes[i].set_title(choice_labels[i])
    for j in range(len(labels)):
        axes[i].plot(rolling_average(collective_d[j][i], wsize), label=labels[j])
        axes[i].axhline(y=0.7, color='r', linestyle='--', linewidth=4) 
        
plt.legend()
plt.suptitle('max_preference_val')
# Out:
# Text(0.5, 0.98, 'max_preference_val')

# %%
import numpy as np
from scipy.special import softmax

# %%
ps = softmax([-9999, 0.1, 0.1, 0.1])

# %%
np.random.choice([0,1,2,3], p=[0., 0., 1., 0.], size=2, replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 np.random.choice([0,1,2,3], p=[0., 0., 1., 0.], size=2, replace=False)
#
# File numpy/random/mtrand.pyx:1031, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Fewer non-zero entries in p than size

# %%
labels = ['partner selection', 'random selection']

wsize = 200
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, 1), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    # plt.plot(d)
    plt.axhline(y=0.7, color='r', linestyle='--', linewidth=4) 
    print(labels[ixs], np.mean(d))
plt.legend()
plt.suptitle('max_preference_val average')
# Out:
# partner selection 0.7534462486706675
# random selection 0.7171340003101527
# Text(0.5, 0.98, 'max_preference_val average')

# %% [markdown]
# diversity

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740104',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740139'
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'diversity' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('diversity')

# fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
# wsize = 200
# for i in range(len(labels)):
#     for j in range(len(collective_d[i])):
#         axes[i].plot(rolling_average(collective_d[i][j], wsize))
#     axes[i].set_title(labels[i])
# plt.suptitle('select_more_variable')
# Out:
# selection 0.49400065178441804
# random 0.5754767969412645
# Text(0.5, 1.0, 'diversity')

# %% [markdown]
# population_avg_choice_matches_preference_data

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740104',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740139'
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'population_avg_choice_matches_preference_data' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('Freq of choice matches preference')

# fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
# wsize = 200
# for i in range(len(labels)):
#     for j in range(len(collective_d[i])):
#         axes[i].plot(rolling_average(collective_d[i][j], wsize))
#     axes[i].set_title(labels[i])
# plt.suptitle('select_more_variable')
# Out:
# selection 0.7950292539628125
# random 0.5381171790290223
# Text(0.5, 1.0, 'Freq of choice matches preference')

# %% [markdown]
# Avg entropy

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740104',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740139'
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'population_mean_entropy_data' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('Avg entropy')

# fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
# wsize = 200
# for i in range(len(labels)):
#     for j in range(len(collective_d[i])):
#         axes[i].plot(rolling_average(collective_d[i][j], wsize))
#     axes[i].set_title(labels[i])
# plt.suptitle('select_more_variable')
# Out:
# selection 0.0881910213876834
# random 0.0224091629771821
# Text(0.5, 1.0, 'Avg entropy')

# %% [markdown]
# avg successful coordination rates

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740104',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_20250311-20031741740139'
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'population_avg_same_choices_data' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 200
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('Avg successful coordination')

# fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
# wsize = 200
# for i in range(len(labels)):
#     for j in range(len(collective_d[i])):
#         axes[i].plot(rolling_average(collective_d[i][j], wsize))
#     axes[i].set_title(labels[i])
# plt.suptitle('select_more_variable')
# Out:
# selection 0.836120966599025
# random 0.8425215280020023
# Text(0.5, 1.0, 'Avg successful coordination')

# %% [markdown]
# Freq of selecting more variable partner

# %%
folders = [
    'test_marl_learned_sym_cost0.1_dynamic_sampling_weights_test_rmV2_action7_20250312-16031741812222',
    'test_marl_random_sym_cost0.1_dynamic_sampling_weights_test_rmV2_action7_20250312-16031741812252'
]
folders = [
    'learned_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166700',
    'random_marl_free_choice_beforehand_num_steps_30_seed1_20250316-19031742166718'
]
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'select_more_entropic' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
labels = ['simple learning', 'simple random', 'selection', 'random']
labels = ['selection', 'random']
# labels = ['partner selection w/o var information', 'random selection']

# alpha = 0.99
wsize = 100
for ixs, d in enumerate(collective_d_avg):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
    print(labels[ixs], np.mean(d))
plt.legend()
plt.title('Mean select_more_variable')

fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective_d[i])):
        axes[i].plot(rolling_average(collective_d[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('select_more_variable')
# Out:
# selection 0.5291556431517159
# random 0.4976712399381151
# Text(0.5, 0.98, 'select_more_variable')

# %% [markdown]
# Freq of choosing different partners

# %%
folders = [
    'SB_task_v4_learned_selection_reset_var_high_0.6_no_self_var_no_partner_var_with_partner_app_20250218-21021739931370',
    'SB_task_v4_random_reset_var_high_0.6_no_self_var_no_partner_var_no_partner_app_20250218-15021739909689'
]
# folders = ['SB_task_v3_learned_selection_reset_var_high_0.6_no_self_var_no_partner_var_20250218-11021739895679']
collective_d = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'Agent_0' in f:
            if ('selection freq_Agent_1_selected' in f) or ('selection freq_Agent_2_selected' in f):
                sub_dir = os.path.join(parent_dir, f)            
                sub_file = os.listdir(sub_dir)[0]
                data = pd.read_csv(os.path.join(sub_dir, sub_file))
                collective_d[ixs].append(np.nan_to_num(data['Value'].to_numpy()[:], 0))
collective_d_avg = [np.mean(trim_and_calculate_mean(collective_d[i]), axis=0) for i in range(len(collective_d))]

# %%
len(collective_d[0])
# Out:
# 2

# %%
labels = ['Selection lr 0.6 w/o variability value shown']
labels = ['partner selection w/o var information', 'random selection']
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 100
for ixs, d in enumerate(collective_d):
    for ixs_a, d_a in enumerate(d):
        try:
            axes[ixs].plot(rolling_average(d[ixs_a], wsize), label=labels[ixs])
        except:
            plt.plot(rolling_average(d[ixs_a], wsize), label=labels[ixs])
    try:
        axes[ixs].set_title(labels[ixs])
    except:
        plt.title(labels[ixs])
plt.suptitle('Freq of agents being selected')
plt.tight_layout()

# %% [markdown]
# encounter_coins

# %%
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

entity_name = 'Coin'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)            
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:]) # trim if needed

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'Coin'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    file = os.listdir(sub_dir)[0]
                    data = pd.read_csv(os.path.join(sub_dir, file))

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']


alpha = 0.2
wsize = 50
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Coin')
# Out:
# Text(0.5, 1.0, 'Coin')

# %%
smoothed_collective_= [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, 'sem', title='coin')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 200
for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Coin')
# Out:
# Text(0.5, 0.98, 'Coin')

# %% [markdown]
# Gem

# %%
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

entity_name = 'Gem'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'Gem'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    file = os.listdir(sub_dir)[0]
                    data = pd.read_csv(os.path.join(sub_dir, file))

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']


alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Gem')
# Out:
# Text(0.5, 1.0, 'Gem')

# %%
smoothed_collective_= [rolling_average(d, 50) for d in collective_]
plot_average_trajectory(smoothed_collective_, 'sem', title='gem')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500

for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Gem')
# Out:
# Text(0.5, 0.98, 'Gem')

# %% [markdown]
# bone

# %%
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

entity_name = 'Bone'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]
# Out:
# /Users/socialai2/miniconda3/envs/state_punishment/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/socialai2/miniconda3/envs/state_punishment/lib/python3.9/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'Bone'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    file = os.listdir(sub_dir)[0]
                    data = pd.read_csv(os.path.join(sub_dir, file))

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']


alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Bone')
# Out:
# Text(0.5, 1.0, 'Bone')

# %%
fig, axes = plt.subplots(1, len(labels), figsize=(4*len(labels),4))
wsize = 500

for i in range(len(labels)):
    for j in range(len(collective[i])):
        axes[i].plot(rolling_average(collective[i][j], wsize))
    axes[i].set_title(labels[i])
plt.suptitle('Bone')
# Out:
# Text(0.5, 0.98, 'Bone')

# %% [markdown]
# wall

# %%
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

entity_name = 'Wall'
collective = [[] for _ in range(len(folders))]

for ixs, folder in enumerate(folders):

    parent_dir = os.path.join('res', folder)
    items = os.listdir(parent_dir)

    for item in items:

        if entity_name in item:

            sub_dir = os.path.join(parent_dir, item)
            file = os.listdir(sub_dir)[0]
            data = pd.read_csv(os.path.join(sub_dir, file))
            collective[ixs].append(data['Value'].to_numpy()[:])

collective_ = [np.mean(collective[i], axis=0) for i in range(len(collective))]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'Wall'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    file = os.listdir(sub_dir)[0]
                    data = pd.read_csv(os.path.join(sub_dir, file))

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']


alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('Wall')
plt.xticks([10000*i for i in range(11)], [f'{i}e+4' for i in range(11)], rotation=30);

# %% [markdown]
# state_punishment_level

# %%
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]
collective = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'state_punishment_level_avg' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective[ixs].append(data['Value'].to_numpy()[:])
collective_ = [np.mean(trim_and_calculate_mean(collective[i]), axis=0) for i in range(len(collective))]

# %%
collective
# Out:
# [[array([0.        , 0.        , 0.465     , ..., 0.90750003, 0.92250001,
#          0.90249997])],
#  [array([0.0025    , 0.        , 0.        , ..., 0.815     , 0.79500002,
#          0.6825    ])],
#  [array([0.54250002, 0.95749998, 0.97500002, ..., 0.88999999, 0.75749999,
#          0.86000001])]]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'state_punishment_level_avg'
agents_num = [1,1,1] # specify the number of agents in each condition
collective = [[] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    try: 
                        file = os.listdir(sub_dir)[0]
                        # data = pd.read_csv(os.path.join(sub_dir, file))
                    except: 
                        data = pd.read_csv(sub_dir)
                    
                    collective[ixs].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*condition_data)))] for condition_data in collective]
collective_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
collective_processed[2].shape
# Out:
# (108124,)

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']


alpha = 0.2
wsize = 200
for ixs, d in enumerate(collective_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    plt.plot(rolling_average(d, wsize), label=labels[ixs])
plt.legend()
plt.title('punishment prob')
# Out:
# Text(0.5, 1.0, 'punishment prob')

# %% [markdown]
# vote

# %%
# vote for punishment
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]
collective_for = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'vote_for_punishment' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_for[ixs].append(data['Value'].to_numpy()[:])
collective_for_ = [np.mean(trim_and_calculate_mean(collective_for[i]), axis=0) for i in range(len(collective_for))]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'vote_for_punishment'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    data = pd.read_csv(sub_dir)

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_for_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
# vote against punishment
folders = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]
collective_against = [[] for _ in range(len(folders))]
for ixs, folder in enumerate(folders):
    parent_dir = os.path.join('res', folder)
    files = os.listdir(parent_dir)

    for f in files:
        if 'vote_against_punishment' in f:
            data = pd.read_csv(os.path.join(parent_dir, f))
            collective_against[ixs].append(data['Value'].to_numpy()[:])
collective_against_ = [np.mean(trim_and_calculate_mean(collective_against[i]), axis=0) for i in range(len(collective_against))]

# %%
# combine different checkpoints
folders_1 = [
    'testvote_withseparateTime_boostrap_withEndDone_test2agents_20241219-11121734627418',
    'testvote_withseparateTime_boostrap_withEndDone_test3agents_20241209-21121733796887',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_20241211-09121733926918',
]

folders_2 = [
    '',
    '',
    'testvote_withseparateTime_boostrap_withEndDone_test6agents_resume_20241219-11121734626833'
]

folders_all = [folders_1, folders_2]

entity_name = 'vote_against_punishment'
agents_num = [2,3,6] # specify the number of agents in each condition
collective = [[[] for _ in range(agents_num[folder_ixs])] for folder_ixs in range(len(folders_1))]


for folders_ixs, folders in enumerate(folders_all):
    for ixs, folder in enumerate(folders):
        if folder != '':
            parent_dir = os.path.join('res', folder)
            items = os.listdir(parent_dir)

            for item in items:

                if entity_name in item:

                    sub_dir = os.path.join(parent_dir, item)
                    data = pd.read_csv(sub_dir)

                    for a in range(len(collective[ixs])):
                        if f'Agent_{a}' in item:
                            collective[ixs][a].append(data['Value'].to_numpy()[:])

collective_processed = [[np.array(list(itertools.chain(*agent_condition_data))) for agent_condition_data in condition_data]
                        for condition_data in collective]
collective_against_ = [np.mean(trim_and_calculate_mean(collective_processed[i]), axis=0) for i in range(len(collective_processed))]

# %%
labels = ['2 Aagents', '3 Aagents', '6 Aagents']
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

alpha = 0.2
wsize = 400
for ixs, d in enumerate(collective_against_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    axes[0].plot(rolling_average(d, wsize), label=labels[ixs]+'_vote_against')
for ixs, d in enumerate(collective_for_):
    # plt.plot(exponential_moving_average(d, alpha), label=labels[ixs])
    axes[1].plot(rolling_average(d, wsize), label=labels[ixs]+'_vote_for')
plt.legend()
axes[0].set_title('decrease')
axes[1].set_title('increase')
# Out:
# Text(0.5, 1.0, 'increase')
